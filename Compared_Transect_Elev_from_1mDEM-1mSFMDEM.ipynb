# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import matplotlib.colors as colors 
import matplotlib as mpl 
# %matplotlib inline

# %%
dirn="c:/jhigh/Projects/"
fn="Transect_points_elevations_from_1mDEM-1mSFMDEM.csv"
print(dirn + fn)
fullpathn = dirn + fn
# Out:
# c:/jhigh/Projects/Transect_points_elevations_from_1mDEM-1mSFMDEM.csv

# %%
df=pd.read_csv(fullpathn, header = 0, skiprows=0, delimiter=',')
print("Read: ",len(df.index),' lines.')
df
# Out:
# Read:  235  lines.
#               X            Y      ELEV  LABEL
# 0    385924.049  4621601.180  0.052000      5
# 1    385924.436  4621600.720  0.060000      6
# 2    385924.403  4621600.740  0.059000      7
# 3    385932.426  4621570.795  0.108000      8
# 4    385960.578  4621550.622  0.158000      9
# 5    385990.353  4621545.638  0.159000     10
# 6    386011.577  4621536.262  0.106000     11
# 7    386025.052  4621525.232  0.058000     12
# 8    386036.151  4621516.255  0.020000     13
# 9    386055.491  4621504.708  0.023000     14
# 10   386042.385  4621497.570  0.049000     15
# 11   386057.915  4621472.025  0.019000     16
# 12   386074.109  4621442.861  0.020000     17
# 13   386091.792  4621430.803  0.002048     18
# 14   386100.635  4621447.040  0.027000     19
# 15   386121.864  4621457.551  0.000652     20
# 16   386132.249  4621458.906 -0.050000     21
# 17   386130.226  4621475.880 -0.009818     22
# 18   386136.107  4621488.164 -0.001473     23
# 19   386154.991  4621465.552 -0.009376     25
# 20   386161.956  4621441.779  0.008718     26
# 21   386171.288  4621422.454  0.008606     27
# 22   386181.440  4621415.124  0.040000     28
# 23   386171.963  4621379.723  0.033000     29
# 24   386183.059  4621367.656  0.013000     30
# 25   386173.694  4621336.165  0.059000     31
# 26   386197.499  4621328.765  0.028000     32
# 27   386191.097  4621283.181  0.034000     33
# 28   386191.277  4621261.875  0.022000     34
# 29   386174.748  4621268.995  0.038000     35
# ..          ...          ...       ...    ...
# 205  385911.667  4621419.632  0.098000    218
# 206  385920.273  4621441.174  0.118000    219
# 207  385915.315  4621490.953  0.101000    220
# 208  385909.135  4621547.740  0.061000    221
# 209  385922.436  4621548.617  0.129000    222
# 210  385937.603  4621550.024  0.137000    223
# 211  385951.580  4621555.558  0.148000    224
# 212  385987.750  4621547.668  0.148000    225
# 213  386035.067  4621550.466  0.071000    226
# 214  386081.397  4621536.218  0.017000    227
# 215  386097.948  4621529.305  0.005756    228
# 216  386122.983  4621497.600 -0.013000    229
# 217  386132.615  4621472.066  0.000953    230
# 218  386133.107  4621457.959 -0.007544    231
# 219  386151.209  4621460.828  0.012000    232
# 220  386162.061  4621501.853 -0.007115    234
# 221  386161.240  4621546.824 -0.015000    235
# 222  386166.277  4621563.428 -0.032000    236
# 223  386168.158  4621573.437 -0.051000    237
# 224  386170.263  4621582.421 -0.076000    238
# 225  386172.111  4621593.173 -0.076000    239
# 226  386174.054  4621601.862 -0.097000    240
# 227  386175.812  4621608.994 -0.118000    241
# 228  386178.088  4621617.801 -0.173000    242
# 229  386179.981  4621627.012 -0.233000    243
# 230  386188.542  4621619.607 -0.137000    244
# 231  386201.000  4621609.419 -0.127000    245
# 232  386213.364  4621596.180 -0.058000    246
# 233  386226.809  4621580.037 -0.186000    247
# 234  386238.551  4621569.360 -0.001494    248
#
# [235 rows x 4 columns]

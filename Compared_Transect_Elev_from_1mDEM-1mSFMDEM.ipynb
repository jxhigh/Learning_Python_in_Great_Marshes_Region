# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import matplotlib.colors as colors 
import matplotlib as mpl 
# %matplotlib inline

# %%
dirn="c:/jhigh/Projects/"
fn="Extracted_Transect_points_elevations_from_1mDEM-1mSFMDEM_pointsdeleted.csv"
print(dirn + fn)
fullpathn = dirn + fn
# Out:
# c:/jhigh/Projects/Extracted_Transect_points_elevations_from_1mDEM-1mSFMDEM_pointsdeleted.csv

# %%
df=pd.read_csv(fullpathn, header = 0, skiprows=0, delimiter=',')
print("Read: ",len(df.index),' lines.')
df
# Out:
# Read:  221  lines.
#               X            Y      ELEV  LABEL
# 0    385924.049  4621601.180  0.052000      5
# 1    385924.436  4621600.720  0.060000      6
# 2    385924.403  4621600.740  0.059000      7
# 3    385932.426  4621570.795  0.108000      8
# 4    385960.578  4621550.622  0.158000      9
# 5    385990.353  4621545.638  0.159000     10
# 6    386011.577  4621536.262  0.106000     11
# 7    386025.052  4621525.232  0.058000     12
# 8    386036.151  4621516.255  0.020000     13
# 9    386055.491  4621504.708  0.022000     14
# 10   386042.385  4621497.570  0.049000     15
# 11   386057.915  4621472.025  0.019000     16
# 12   386074.109  4621442.861  0.020000     17
# 13   386091.792  4621430.803  0.002050     18
# 14   386100.635  4621447.040  0.027000     19
# 15   386121.864  4621457.551  0.000653     20
# 16   386132.249  4621458.906 -0.050000     21
# 17   386130.226  4621475.880 -0.009828     22
# 18   386136.107  4621488.164 -0.001472     23
# 19   386154.991  4621465.552 -0.009375     25
# 20   386161.956  4621441.779  0.008718     26
# 21   386171.288  4621422.454  0.008605     27
# 22   386181.440  4621415.124  0.040000     28
# 23   386171.963  4621379.723  0.033000     29
# 24   386183.059  4621367.656  0.013000     30
# 25   386173.694  4621336.165  0.059000     31
# 26   386197.499  4621328.765  0.028000     32
# 27   386191.097  4621283.181  0.034000     33
# 28   386191.277  4621261.875  0.022000     34
# 29   386174.748  4621268.995  0.038000     35
# ..          ...          ...       ...    ...
# 191  385911.667  4621419.632  0.098000    218
# 192  385920.273  4621441.174  0.118000    219
# 193  385915.315  4621490.953  0.101000    220
# 194  385909.135  4621547.740  0.061000    221
# 195  385922.436  4621548.617  0.129000    222
# 196  385937.603  4621550.024  0.137000    223
# 197  385951.580  4621555.558  0.148000    224
# 198  385987.750  4621547.668  0.148000    225
# 199  386035.067  4621550.466  0.071000    226
# 200  386081.397  4621536.218  0.017000    227
# 201  386097.948  4621529.305  0.005759    228
# 202  386122.983  4621497.600 -0.013000    229
# 203  386132.615  4621472.066  0.000955    230
# 204  386133.107  4621457.959 -0.007547    231
# 205  386151.209  4621460.828  0.012000    232
# 206  386162.061  4621501.853 -0.007108    234
# 207  386161.240  4621546.824 -0.015000    235
# 208  386166.277  4621563.428 -0.032000    236
# 209  386168.158  4621573.437 -0.051000    237
# 210  386170.263  4621582.421 -0.076000    238
# 211  386172.111  4621593.173 -0.076000    239
# 212  386174.054  4621601.862 -0.097000    240
# 213  386175.812  4621608.994 -0.118000    241
# 214  386178.088  4621617.801 -0.173000    242
# 215  386179.981  4621627.012 -0.233000    243
# 216  386188.542  4621619.607 -0.137000    244
# 217  386201.000  4621609.419 -0.127000    245
# 218  386213.364  4621596.180 -0.058000    246
# 219  386226.809  4621580.037 -0.186000    247
# 220  386238.551  4621569.360 -0.001500    248
#
# [221 rows x 4 columns]

# %%
df.describe()
# Out:
#                    X             Y        ELEV       LABEL
# count     221.000000  2.210000e+02  221.000000  221.000000
# mean   386120.444792  4.621226e+06    0.053894  124.226244
# std       140.917483  2.509418e+02    0.078654   71.846828
# min    385883.459000  4.620667e+06   -0.233000    5.000000
# 25%    385999.603000  4.621118e+06    0.016000   62.000000
# 50%    386117.050000  4.621237e+06    0.060000  121.000000
# 75%    386199.743000  4.621404e+06    0.105000  189.000000
# max    386407.741000  4.621627e+06    0.458000  248.000000

# %%
binedges= np.arange(-.4,.45, .05)
binedges
# Out:
# array([-4.00000000e-01, -3.50000000e-01, -3.00000000e-01, -2.50000000e-01,
#        -2.00000000e-01, -1.50000000e-01, -1.00000000e-01, -5.00000000e-02,
#        -1.11022302e-16,  5.00000000e-02,  1.00000000e-01,  1.50000000e-01,
#         2.00000000e-01,  2.50000000e-01,  3.00000000e-01,  3.50000000e-01,
#         4.00000000e-01])

# %%
val = df["ELEV"].values
plt.hist(val, bins= binedges)
#df.hist(column= "ELEV")
plt.xlabel("1mDEM-1mSFMDEM(m)")
plt.ylabel("Total Amount")
plt.savefig("Hist_1mDEM-1mSFMDEM_Elevation_Differences.png")

# %%
df.plot(kind='scatter', x='X', y='Y', c="ELEV", cmap= "jet")
plt.xlabel("1mDEM-1mSFMDEM(m)")
plt.ylabel("Local_N")
plt.savefig("Position_Scatter_1mDEM-1mSFMDEM_Transects_ElevDif.png")

# %%
df["ELEV"].describe()
rmse=np.sqrt(np.mean(val**2))
print(df["ELEV"].describe())
print("rmse=", rmse)
# Out:
# count    221.000000
# mean       0.053894
# std        0.078654
# min       -0.233000
# 25%        0.016000
# 50%        0.060000
# 75%        0.105000
# max        0.458000
# Name: ELEV, dtype: float64
# rmse= 0.09519947836682566
